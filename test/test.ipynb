# %%
import numpy as np
data = np.linspace(1, 10, num=100)
target = np.sin(data) + np.random.random(size=100)#添加噪声
data = data.reshape((-1, 1))
print("data")
print(data)
print("target")
print(target)
# Out:
# data
# [[ 1.        ]
#  [ 1.09090909]
#  [ 1.18181818]
#  [ 1.27272727]
#  [ 1.36363636]
#  [ 1.45454545]
#  [ 1.54545455]
#  [ 1.63636364]
#  [ 1.72727273]
#  [ 1.81818182]
#  [ 1.90909091]
#  [ 2.        ]
#  [ 2.09090909]
#  [ 2.18181818]
#  [ 2.27272727]
#  [ 2.36363636]
#  [ 2.45454545]
#  [ 2.54545455]
#  [ 2.63636364]
#  [ 2.72727273]
#  [ 2.81818182]
#  [ 2.90909091]
#  [ 3.        ]
#  [ 3.09090909]
#  [ 3.18181818]
#  [ 3.27272727]
#  [ 3.36363636]
#  [ 3.45454545]
#  [ 3.54545455]
#  [ 3.63636364]
#  [ 3.72727273]
#  [ 3.81818182]
#  [ 3.90909091]
#  [ 4.        ]
#  [ 4.09090909]
#  [ 4.18181818]
#  [ 4.27272727]
#  [ 4.36363636]
#  [ 4.45454545]
#  [ 4.54545455]
#  [ 4.63636364]
#  [ 4.72727273]
#  [ 4.81818182]
#  [ 4.90909091]
#  [ 5.        ]
#  [ 5.09090909]
#  [ 5.18181818]
#  [ 5.27272727]
#  [ 5.36363636]
#  [ 5.45454545]
#  [ 5.54545455]
#  [ 5.63636364]
#  [ 5.72727273]
#  [ 5.81818182]
#  [ 5.90909091]
#  [ 6.        ]
#  [ 6.09090909]
#  [ 6.18181818]
# ...
